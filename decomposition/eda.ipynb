# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
import pandas as pd
import glob

folder_path = 'dataset/*.csv'
files = glob.glob(folder_path)

dfs = []

for file in files:
    df = pd.read_csv(file)
    dfs.append(df)

# %%
df_0 = dfs[0]
df_1 = dfs[1]
df_2 = dfs[2]
df_3 = dfs[3]
df_4 = dfs[4]
df_5 = dfs[5]
df_6 = dfs[6]
df_7 = dfs[7]
df_8 = dfs[8]
df_9 = dfs[9]
df_10 = dfs[10]

# %%
def plot_decomposition(scenario_df):
    # Decompose the time series
    result = seasonal_decompose(scenario_df['Amount LC'], model='additive', period=30)

    # Extract components
    observed = result.observed
    trend = result.trend
    seasonal = result.seasonal
    residual = result.resid

    # Create a subplot for interactive plots
    fig = make_subplots(rows=4, cols=1, shared_xaxes=True, 
                    subplot_titles=("Observed", "Trend", "Seasonality", "Residuals"))

    # Observed
    fig.add_trace(go.Scatter(x=observed.index, y=observed, mode='lines', name='Observed'), row=1, col=1)

    # Trend
    fig.add_trace(go.Scatter(x=trend.index, y=trend, mode='lines', name='Trend', line=dict(color='orange')), row=2, col=1)

    # Seasonality
    fig.add_trace(go.Scatter(x=seasonal.index, y=seasonal, mode='lines', name='Seasonality', line=dict(color='green')), row=3, col=1)

    # Residuals
    fig.add_trace(go.Scatter(x=residual.index, y=residual, mode='lines', name='Residuals', line=dict(color='red')), row=4, col=1)

    # Update layout
    fig.update_layout(height=800, width=1000, title="Time Series Decomposition",
                  showlegend=False, template="plotly_white")

    # Show the interactive plot
    fig.show()

# %%
plot_decomposition(df_1)

# %%
plot_decomposition(df_2)

# %%
plot_decomposition(df_3)

# %%
plot_decomposition(df_4)

# %%
plot_decomposition(df_5)

# %%
plot_decomposition(df_6)

# %%
plot_decomposition(df_7)

# %%
plot_decomposition(df_8)

# %%
plot_decomposition(df_9)

# %%
plot_decomposition(df_10)
